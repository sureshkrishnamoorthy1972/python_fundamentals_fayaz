# %% [markdown]
# # ![1_dlRLsiPLNGhWVZvdKQJMWQ.png](attachment:1_dlRLsiPLNGhWVZvdKQJMWQ.png)

# %% [markdown]
# # Deepdive into Lists

# %%
my_students = ['Narendranath','Suresh', 'Satish', 'Pramod', 'Sanal']

# %%
my_students
# Out:
# ['Narendranath', 'Suresh', 'Satish', 'Pramod', 'Sanal']

# %% [markdown]
# # How to add the elements in the List data type

# %%
my_students.append('Gyanesh')

# %%
my_students
# Out:
# ['Narendranath', 'Suresh', 'Satish', 'Pramod', 'Sanal', 'Gyanesh']

# %% [markdown]
# # How to add an element at particular Index no

# %%
my_students[1]='Mahender'

# %%
my_students
# Out:
# ['Narendranath', 'Mahender', 'Satish', 'Pramod', 'Sanal', 'Gyanesh', 1]

# %%
my_list =['a', 'b','d']

# %%
my_list.insert(2,'c')

# %%
print(my_list)
# Out:
# ['a', 'b', 'c', 'd']

# %%
my_color = ['blue','red','violet','green']

# %%
my_color.insert(0,'purple')

# %%
print(my_color)
# Out:
# ['purple', 'blue', 'red', 'violet', 'green']

# %%
Company =['Julia', 'Deepti', 'Manu', 'Bagya']

# %% [markdown]
# Requirement: Please add Reshma at Index No.3

# %%
Company.insert(2,'Reshma')

# %%
Company
# Out:
# ['Julia', 'Deepti', 'Reshma', 'Manu', 'Bagya']

# %% [markdown]
# Requirement: Pl add Shalini in the above list

# %%
Company.append('Shalini')

# %%
Company
# Out:
# ['Julia', 'Deepti', 'Reshma', 'Manu', 'Bagya', 'Shalini']

# %% [markdown]
# # How to remove an element from the List

# %%
animals = ['cat', 'dog', 'mouse']

# %%
#del function

# %%
del animals[2]

# %%
animals
# Out:
# ['cat', 'dog']

# %%
# Pop Function

# %%
animals.pop()
# Out:
# 'dog'

# %%
animals
# Out:
# ['cat']

# %% [markdown]
# # Organizing a List

# %%
students = ['Manisha', 'Sandhya', 'Bhavana', 'Murali', 'Anisha']

# %%
print(students)
# Out:
# ['Manisha', 'Sandhya', 'Bhavana', 'Murali', 'Anisha']

# %% [markdown]
# Re-arranging the List in an alphabetical order

# %% [markdown]
# Permanent Method

# %%
students.sort() #this command will make the change permanently

# %%
print(students)
# Out:
# ['Anisha', 'Bhavana', 'Manisha', 'Murali', 'Sandhya']

# %% [markdown]
# Temporary Method

# %%
students1 =['Rajesh', 'Prashanth', 'Deepak', 'Venky', 'Sathish']

# %%
print(students1)
# Out:
# ['Rajesh', 'Prashanth', 'Deepak', 'Venky', 'Sathish']

# %% [markdown]
# # SORTING NUMBERS

# %%
numbers = [3,51,2,8,6]

# %%
numbers.sort()

# %%
numbers
# Out:
# [2, 3, 6, 8, 51]

# %%
numbers.sort(reverse=True)

# %%
numbers
# Out:
# [51, 8, 6, 3, 2]
